# %% [markdown]
# # One hot encoding the iris-dataset
#
# In this notebook you'll apply the one-hot encoding technique in the iris-dataset. It won't lead to any good results, but it'll give you the chance to get to know the tools you can use to do on hot encoding or, alternatively, a more standard logistic regression.

# %% [markdown]
# First import the data.

# %%
import pandas as pd
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['species'] = iris.target

print(df.head())

# %% [markdown]
# ## Without one-hot encoding
#
# Create an X and a y-dataset (capital X: multiple columns, lower case y: only one column), with X having all columns except for "species" and y containing only "species". Next split it into a training and test set, using about 40% data as test-size.
#
# Set the random state to a known number.

# %%
# Up to you!

# %% [markdown]
# Now train a logistic regression model and calculate the accuracy.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Train the model
lr_model = LogisticRegression(max_iter=200)
lr_model.fit(X_train, y_train)

# Make predictions and evaluate the model
y_pred = lr_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# %% [markdown]
# The accuracy way to high. An accuracy of 1.0 can happen due to the simplicity and separability of the Iris dataset, and using a specific random split might have resulted in a particularly easy-to-classify test set. Checking with cross-validation will help confirm if your model is truly that accurate across different splits.
#
# Try a cross-validation score!

# %%
# Up to you!

# %% [markdown]
# The mean cross-validation score is 0.973, which is lower but not very low. It is a test set in the end...

# %% [markdown]
# ## With one-hot encoding
#
# Next step! Let's apply one hot encoding to the species-column. Use the get_dummies-function from pandas.

# %%
# Up to you!

# %% [markdown]
# Now do another train/test-split using the same random state and 40% test-size.

# %%
from sklearn.model_selection import train_test_split

# Features and target variable
X = df_encoded.drop(columns=['species_0', 'species_1', 'species_2'])
y = df_encoded[['species_0', 'species_1', 'species_2']]

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %% [markdown]
# With this done we can use a random forest classifier as model. Train it and show the accuracy.

# %%
# Up to you!

# %% [markdown]
# 98.3% is pretty high, although not as high as the logistic regression. What does the cross-validation look like?

# %%
# Up to you!

# %% [markdown]
# Only 91%. As we said the notebook doesn't prove that one-hot encoding is always the best of ideas, but hopefully it did log the option into your mindset.
