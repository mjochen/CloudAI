# %% [markdown]
# # Breast cancer - one hot encodig
#
# This is an exercise using the [breast cancer-dataset](https://raw.githubusercontent.com/jbrownlee/Datasets/master/breast-cancer.csv) (No need to download again, it's already in the files-folder.) This data has no numerical columns, they are all categorical.
#
# The example is being used from [this tutorial.](https://machinelearningmastery.com/one-hot-encoding-for-categorical-data/)

# %% [markdown]
# ## Data preparation
#
# Let's start by importing a lot of libraries.

# %%
from numpy import mean
from numpy import std
import numpy as np
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import accuracy_score

# %% [markdown]
# And load the actual file. Note how we're storing the data as a numpy-array. We're only using pandas to load the csv. No worries, as you know how numpy works.

# %%
file = "files/breast-cancer.csv"
dataset = read_csv(file, header=None)
# retrieve the array of data
data = dataset.values

data[:5]

# %% [markdown]
# Next, split the data in an X (input-fields, capital because there are many of them) and y (output, lowercase because there is just the one field).

# %%
# Up to you!

# %% [markdown]
# Print X. Notice how the fields still contain a "'"? Remove it!

# %%
# Up to you!

# %% [markdown]
# ## Ordinal encoder transform
#
# As a first step we'll transform all labels into integer values. In the first step we'll ignore any ordinal value in the data, meaning that even when a column clearly has an order (like the age-group) we won't take this into account when encoding (class "1" could be older than "2" which could be younger than "3").
#
# The functions we are using do allow passing this ordinal information when encoding, so in a next step we'll implement any ordinal information we have and check to see if the model becomes better. Now create a ordinal encoder without ordinal information and fit_transform X.
#
# Don't store in X, we'll be reusing that to try the same with the ordinal values.

# %%
# Up to you!

# %% [markdown]
# We applied this model to the X-data, but we should fit it to the train and test-sets, as they are the ones we will be using when building the models.

# %%
# Up to you!

# %% [markdown]
# To see which columns are ordinal, we can look at the [description of the dataset](https://raw.githubusercontent.com/jbrownlee/Datasets/master/breast-cancer.names). There we read the following:
#
# 1. Class: no-recurrence-events, recurrence-events
# 2. age: 10-19, 20-29, 30-39, 40-49, 50-59, 60-69, 70-79, 80-89, 90-99.
# 3. menopause: lt40, ge40, premeno.
# 4. tumor-size: 0-4, 5-9, 10-14, 15-19, 20-24, 25-29, 30-34, 35-39, 40-44,
#                 45-49, 50-54, 55-59.
# 5. inv-nodes: 0-2, 3-5, 6-8, 9-11, 12-14, 15-17, 18-20, 21-23, 24-26,
#                 27-29, 30-32, 33-35, 36-39.
# 6. node-caps: yes, no.
# 7. deg-malig: 1, 2, 3.
# 8. breast: left, right.
# 9. breast-quad: left-up, left-low, right-up,	right-low, central.
# 10. irradiat:	yes, no.
#
# Of these the columns "age", "tumor-size", "inv-nodes" and "deg-malig" seem to be the most ordered. First, create the [categories](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OrdinalEncoder.html)-variable you'll be needing. To do this, copy the output from "ordinal_without.categories_" to get a properly formatted array. Next, make sure the data is in the correct orde.
#
# (PS: Don't copy-paste all the values, but copy the list you find above (10-19, 20-29, ...) as a string and use "split".)

# %%
# Up to you!

# %% [markdown]
# And naturally the order of the columns in the CSV-files isn't the same as the one above. The first line look like this:
#
# ```
# '40-49','premeno','15-19','0-2','yes','3','right','left_up','no','recurrence-events'
# ```
#
# Create the categories-list based on that line. Store the lists we made before on the correct postion and fill up the non-ordinal values with the string 'auto'.

# %%
# Up to you!

# %% [markdown]
# Apply this to your train and test sets as well.

# %%
# Up to you!

# %% [markdown]
# For the y-variable there's no need to make a difference between ordered and ordered as we are using a label-encoder.

# %%
# Up to you!

# %% [markdown]
# The result of all this work is that we now have the same data, but stored nicely in integers, not in labels.

# %%
print('Input', X_with.shape)
print(X_with[:5, :])
print('Input', X_without.shape)
print(X_without[:5, :])
print('Output', y.shape)
print(y[:5])

# %% [markdown]
# Next, split in test and training sets, using 33% of your data as test-set. Use a "random_state" of 2 to get the same results as this example.

# %% [markdown]
# Finally, train a model on X_train_with and X_train_without and see what results you are getting.

# %%
# Up to you!

# %%
# Up to you!

# %% [markdown]
# Accuracy should be around 70% with the ordinals included and 73% without which is actually a decrease.

# %% [markdown]
# ## One hot encoding the data
#
# Using one hot encoding comes down to using a different encoder on the same data. Since we didn't mess up X we don't have to load the data again.

# %%
# Up to you!

# %% [markdown]
# Apply to train and test sets.

# %%
# one-hot encode input variables
onehot_encoder = OneHotEncoder()
onehot_encoder.fit(X)
X_train = onehot_encoder.transform(X_train)
X_test = onehot_encoder.transform(X_test)

# %% [markdown]
# And fit a logistic regression model!

# %%
# Up to you!

# %% [markdown]
# Accuracy is once again around 70%. The results we got aren't that impressive, but the main point was to show the different ways of encoding categoricals.
