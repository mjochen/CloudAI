# %% [markdown]
# # Wine classifier
#
# We just did a lot of work on a regressor, now let's try a classifier. We'll have another go at the wine dataset.
#
# * Import the data
# * Split into train and test
# * Train a couple of classification models, keeping track of precision (or recall, or...)
#     * Tune where possible using KFold and gridsearch
# * Combine the results
# * Train a meta-model
# * Stack all models together
# * Test what kind of metrics you get in the end!

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Load and prepare the data
X, y = load_wine(return_X_y=True)

# %%
# Up to you!
